# %%
import tensorflow_model_analysis as tfma
import pandas as pd
# Out:
# /home/manjula/anaconda3/envs/tfx-env/lib/python3.7/site-packages/google/auth/crypt/_cryptography_rsa.py:22: CryptographyDeprecationWarning: Python 3.7 is no longer supported by the Python core team and support for it is deprecated in cryptography. The next release of cryptography will remove support for Python 3.7.
#   import cryptography.exceptions
# 2026-04-17 10:26:38.300354: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-17 10:26:38.385168: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2026-04-17 10:26:38.385187: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2026-04-17 10:26:38.848618: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2026-04-17 10:26:38.848723: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2026-04-17 10:26:38.848732: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
eval_result_1= tfma.load_eval_result(
    '/home/manjula/COMP315/airflow_pipeline_outputs/adult_census_tfx_output/Evaluator/evaluation/69'
)
# Out:
# WARNING:tensorflow:From /home/manjula/anaconda3/envs/tfx-env/lib/python3.7/site-packages/tensorflow_model_analysis/writers/metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /home/manjula/anaconda3/envs/tfx-env/lib/python3.7/site-packages/tensorflow_model_analysis/writers/metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
eval_result_2= tfma.load_eval_result(
    '/home/manjula/COMP315/airflow_pipeline_outputs/adult_census_tfx_output/Evaluator/evaluation/78'
)

# %%
eval_result_3= tfma.load_eval_result(
    '/home/manjula/COMP315/airflow_pipeline_outputs/adult_census_tfx_output/Evaluator/evaluation/94'
)

# %%
m1_slices = eval_result_1.get_metrics_for_all_slices()
m2_slices = eval_result_2.get_metrics_for_all_slices()
m3_slices = eval_result_3.get_metrics_for_all_slices()

for slice_key, m1 in m1_slices.items():
    if slice_key not in m2_slices or slice_key not in m3_slices:
        continue  # skip slices that don't exist in all three runs

    m2 = m2_slices[slice_key]
    m3 = m3_slices[slice_key]

    acc1 = m1.get('binary_accuracy', {})
    acc2 = m2.get('binary_accuracy', {})
    acc3 = m3.get('binary_accuracy', {}) 
    auc1 = m1.get('auc', {})
    auc2 = m2.get('auc', {})
    auc3 = m3.get('auc', {})              

    print(f"\nSlice: {slice_key}")
    print(f"  Run 69 accuracy: {acc1}")
    print(f"  Run 78 accuracy: {acc2}")
    print(f"  Run 94 accuracy: {acc3}")   
    print(f"  Run 69 AUC:      {auc1}")
    print(f"  Run 78 AUC:      {auc2}")
    print(f"  Run 94 AUC:      {auc3}")
# Out:
# Slice: (('sex', 0),)
#   Run 69 accuracy: {'doubleValue': 0.8071930773391022}
#   Run 78 accuracy: {'doubleValue': 0.8053001622498648}
#   Run 94 accuracy: {'doubleValue': 0.8035424553812872}
#   Run 69 AUC:      {'doubleValue': 0.8762290608745932}
#   Run 78 AUC:      {'doubleValue': 0.8741095178102407}
#   Run 94 AUC:      {'doubleValue': 0.8779554391658614}
#
# Slice: ()
#   Run 69 accuracy: {'doubleValue': 0.8442593263310395}
#   Run 78 accuracy: {'doubleValue': 0.8401847156827237}
#   Run 94 accuracy: {'doubleValue': 0.8414523723288664}
#   Run 69 AUC:      {'doubleValue': 0.8991112505574722}
#   Run 78 AUC:      {'doubleValue': 0.8975224685897439}
#   Run 94 AUC:      {'doubleValue': 0.9006800442307348}
#
# Slice: (('race', 0),)
#   Run 69 accuracy: {'doubleValue': 0.8356572645023949}
#   Run 78 accuracy: {'doubleValue': 0.831718999467802}
#   Run 94 accuracy: {'doubleValue': 0.8321447578499201}
#   Run 69 AUC:      {'doubleValue': 0.8950410889730579}
#   Run 78 AUC:      {'doubleValue': 0.892739465887347}
#   Run 94 AUC:      {'doubleValue': 0.896085516076868}
#
# Slice: (('sex', 1),)
#   Run 69 accuracy: {'doubleValue': 0.9194078947368421}
#   Run 78 accuracy: {'doubleValue': 0.9109100877192983}
#   Run 94 accuracy: {'doubleValue': 0.9183114035087719}
#   Run 69 AUC:      {'doubleValue': 0.9192987417043696}
#   Run 78 AUC:      {'doubleValue': 0.919306617302915}
#   Run 94 AUC:      {'doubleValue': 0.9215939161376263}
#
# Slice: (('race', 1),)
#   Run 69 accuracy: {'doubleValue': 0.9021043000914913}
#   Run 78 accuracy: {'doubleValue': 0.898444647758463}
#   Run 94 accuracy: {'doubleValue': 0.9048490393412626}
#   Run 69 AUC:      {'doubleValue': 0.9209726443768994}
#   Run 78 AUC:      {'doubleValue': 0.9217101734310746}
#   Run 94 AUC:      {'doubleValue': 0.9258299064306571}
#
# Slice: (('race', 2),)
#   Run 69 accuracy: {'doubleValue': 0.852054794520548}
#   Run 78 accuracy: {'doubleValue': 0.8465753424657534}
#   Run 94 accuracy: {'doubleValue': 0.8465753424657534}
#   Run 69 AUC:      {'doubleValue': 0.8901799954431533}
#   Run 78 AUC:      {'doubleValue': 0.895933014354067}
#   Run 94 AUC:      {'doubleValue': 0.8992557150451889}
#
# Slice: (('race', 4),)
#   Run 69 accuracy: {'doubleValue': 0.9130434782608695}
#   Run 78 accuracy: {'doubleValue': 0.9021739130434783}
#   Run 94 accuracy: {'doubleValue': 0.9130434782608695}
#   Run 69 AUC:      {'doubleValue': 0.9062918340026774}
#   Run 78 AUC:      {'doubleValue': 0.9143239625167336}
#   Run 94 AUC:      {'doubleValue': 0.9103078982597055}
#
# Slice: (('race', 3),)
#   Run 69 accuracy: {'doubleValue': 0.9292929292929293}
#   Run 78 accuracy: {'doubleValue': 0.9191919191919192}
#   Run 94 accuracy: {'doubleValue': 0.9393939393939394}
#   Run 69 AUC:      {'doubleValue': 0.8759259259259259}
#   Run 78 AUC:      {'doubleValue': 0.8679012345679012}
#   Run 94 AUC:      {'doubleValue': 0.8759259259259259}
